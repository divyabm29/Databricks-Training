# %%
#batch
# wont work for incremental or streaming data
df = spark.read.csv("/Volumes/dev/naval/raw/months/", header = True, inferSchema = True)
df.write.mode("overwrite").option("overWriteSchema", True).saveAsTable("dev.divya_bronze.month)

# %%
# %sql
CREATE TABLE IF NOT EXISTS dev.divya_bronze.sales_incremental;

COPY INTO dev.divya_bronze.sales_incremental
FROM '/Volumes/dev/naval/raw/months/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true', 'inferschema' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true')
