# %%
# %run "/Workspace/Users/divya.m@axa.com/DB training/Day 5: Medallion/includes"

# %%
dbutils.widgets.text("catalog","")
dbutils.widgets.text("table","")
catalog=dbutils.widgets.get("catalog")
table=dbutils.widgets.get("table")

# %%
df = spark.read.csv(f"{input_path}sales.csv", header = True, inferSchema = True)

# %%
df_meta = df.withColumn("ingestion_date", current_timestamp()). withColumn("file_name", col("_metadata.file_name")).withColumn("last_modified_timestamp", col("_metadata.file_modification_time"))

# %%
df=spark.read.csv(f"{input_path}{table}.csv",header=True,inferSchema=True)

df1=add_ingestion_metadata(df)

df1.write.mode("overwrite").saveAsTable(f"{catalog}.divya_bronze.{table}")
