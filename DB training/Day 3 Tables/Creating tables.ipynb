-- %% [markdown]
-- CTAS

-- %%
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

-- %%
CREATE OR REPLACE TABLE dev.divya.adult_income AS
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv");

select * from dev.divya.adult_income limit 5;

-- %%
select * from read_files("/Volumes/dev/naval/raw/house-price.parquet") limit 5;

-- %%
CREATE OR REPLACE TABLE dev.divya.house_price AS
select * from read_files("/Volumes/dev/naval/raw/house-price.parquet");

select * from dev.divya.house_price limit 5;

-- %% [markdown]
-- Parameterizing using SQL

-- %%
select * from 
IDENTIFIER(:catalog || '.' || :schema || '.' || :table)
